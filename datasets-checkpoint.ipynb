# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
print(df.head(5))
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
print(df.tail(5))
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 88         21.0                None      Front  ...        7.0   187.0
# 89         30.0                None      Front  ...        5.0   180.0
# 90         25.0                None      Front  ...        4.0   159.0
# 91         28.0         Driver only       Rear  ...        5.0   190.0
# 92         28.0  Driver & Passenger      Front  ...        5.0   184.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
#        'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
#        'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
#        'Make'],
#       dtype='object')

# %%
print(df['Max.Price'])
# Out:
# 0     18.8
# 1     38.7
# 2     32.3
# 3     44.6
# 4      NaN
#       ...
# 88    22.7
# 89    22.4
# 90    23.7
# 91    23.5
# 92    28.5
# Name: Max.Price, Length: 93, dtype: float64

# %%
print(df.iloc[1])
# Out:
# Manufacturer                         NaN
# Model                             Legend
# Type                             Midsize
# Min.Price                           29.2
# Price                               33.9
# Max.Price                           38.7
# MPG.city                              18
# MPG.highway                           25
# AirBags               Driver & Passenger
# DriveTrain                         Front
# Cylinders                              6
# EngineSize                           3.2
# Horsepower                           200
# RPM                                 5500
# Rev.per.mile                        2335
# Man.trans.avail                      Yes
# Fuel.tank.capacity                    18
# Passengers                             5
# Length                               195
# Wheelbase                            115
# Width                                 71
# Turn.circle                           38
# Rear.seat.room                        30
# ...

# %%
df.head(5)
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
df.groupby(['Model']).count()['Price']
# Out:
# Model
# 100         1
# 190E        1
# 240         1
# 300E        1
# 323         1
#            ..
# Taurus      1
# Tempo       1
# Tercel      1
# Town_Car    1
# Vision      1
# Name: Price, Length: 92, dtype: int64

# %%
print(df['Min.Price'])
print(df['Min.Price'].isnull())
# Out:
# 0     12.9
# 1     29.2
# 2     25.9
# 3      NaN
# 4      NaN
#       ...
# 88    16.6
# 89    17.6
# 90    22.9
# 91    21.8
# 92    24.8
# Name: Min.Price, Length: 93, dtype: float64
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
#       ...
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Name: Min.Price, Length: 93, dtype: bool

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           4
# Model                  1
# Type                   3
# Min.Price             93
# Price                  2
# Max.Price              5
# MPG.city               9
# MPG.highway            2
# AirBags                6
# DriveTrain             7
# Cylinders              5
# EngineSize             2
# Horsepower             7
# RPM                    3
# Rev.per.mile           6
# Man.trans.avail        5
# Fuel.tank.capacity     8
# Passengers             2
# Length                 4
# Wheelbase              1
# Width                  6
# Turn.circle            5
# Rear.seat.room         4
# Luggage.room          19
# Weight                 7
# Origin                 5
# Make                   3
# dtype: int64

# %%
car_Manufacturers = df.groupby('Manufacturer')
priceDf = car_Manufacturers['Manufacturer','Price'].max().sort_values('Price', ascending=False)
priceDf
# Out:
#                 Manufacturer  Price
# Manufacturer
# Mercedes-Benz  Mercedes-Benz   61.9
# Infiniti            Infiniti   47.9
# Cadillac            Cadillac   40.1
# Chevrolet          Chevrolet   38.0
# Audi                    Audi   37.7
# Lincoln              Lincoln   36.1
# Mazda                  Mazda   32.5
# BMW                      BMW   30.0
# Chrysler            Chrysler   29.5
# Saab                    Saab   28.7
# Lexus                  Lexus   28.0
# Buick                  Buick   26.3
# Mitsubishi        Mitsubishi   26.1
# Dodge                  Dodge   25.8
# Pontiac              Pontiac   24.4
# Volkswagen        Volkswagen   23.3
# Toyota                Toyota   22.7
# Volvo                  Volvo   22.7
# Nissan                Nissan   21.5
# Ford                    Ford   20.9
# Oldsmobile        Oldsmobile   20.7
# Honda                  Honda   19.8
# Subaru                Subaru   19.5
# Eagle                  Eagle   19.3
# ...

# %%
df.describe()
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count        0.0  91.000000  88.000000  84.000000    91.000000   91.000000
# mean         NaN  19.616484  21.459091  22.404762    29.065934    2.658242
# std          NaN   9.724280  10.696563   5.841520     5.370293    1.045845
# min          NaN   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%          NaN  12.350000  14.575000  18.000000    26.000000    1.800000
# 50%          NaN  17.700000  19.150000  21.000000    28.000000    2.300000
# 75%          NaN  23.500000  24.825000  25.000000    31.000000    3.250000
# max          NaN  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   86.000000    90.000000     87.000000           85.000000   91.000000
# mean   144.000000  5276.666667   2355.000000           16.683529    5.076923
# ...

# %%
df.mean()
# Out:
# Min.Price                     NaN
# Price                   19.616484
# Max.Price               21.459091
# MPG.city                22.404762
# MPG.highway             29.065934
# EngineSize               2.658242
# Horsepower             144.000000
# RPM                   5276.666667
# Rev.per.mile          2355.000000
# Fuel.tank.capacity      16.683529
# Passengers               5.076923
# Length                 182.865169
# Wheelbase              103.956522
# Width                   69.448276
# Turn.circle             38.954545
# Rear.seat.room          27.853933
# Luggage.room            13.986486
# Weight                3104.593023
# dtype: float64

# %%
df.corr()
# Out:
#                     Min.Price     Price  Max.Price  MPG.city  MPG.highway  \
# Min.Price                 NaN       NaN        NaN       NaN          NaN
# Price                     NaN  1.000000   0.980252 -0.596479    -0.554859
# Max.Price                 NaN  0.980252   1.000000 -0.537724    -0.503579
# MPG.city                  NaN -0.596479  -0.537724  1.000000     0.947916
# MPG.highway               NaN -0.554859  -0.503579  0.947916     1.000000
# EngineSize                NaN  0.607286   0.513480 -0.718253    -0.625965
# Horsepower                NaN  0.794607   0.724528 -0.714274    -0.643573
# RPM                       NaN -0.007644  -0.017815  0.385401     0.304078
# Rev.per.mile              NaN -0.422175  -0.356009  0.709801     0.591147
# Fuel.tank.capacity        NaN  0.604777   0.526891 -0.823445    -0.785317
# Passengers                NaN  0.040890   0.049113 -0.430377    -0.467672
# Length                    NaN  0.564704   0.519279 -0.676105    -0.538247
# ...

# %%
df.count()
# Out:
# Manufacturer          89
# Model                 92
# Type                  90
# Min.Price              0
# Price                 91
# Max.Price             88
# MPG.city              84
# MPG.highway           91
# AirBags               87
# DriveTrain            86
# Cylinders             88
# EngineSize            91
# Horsepower            86
# RPM                   90
# Rev.per.mile          87
# Man.trans.avail       88
# Fuel.tank.capacity    85
# Passengers            91
# Length                89
# Wheelbase             92
# Width                 87
# Turn.circle           88
# Rear.seat.room        89
# Luggage.room          74
# Weight                86
# Origin                88
# Make                  90
# dtype: int64

# %%
df.max()
# Out:
# Min.Price                NaN
# Price                   61.9
# Max.Price               80.0
# MPG.city                46.0
# MPG.highway             50.0
# EngineSize               5.7
# Horsepower             300.0
# RPM                   6500.0
# Rev.per.mile          3755.0
# Fuel.tank.capacity      27.0
# Passengers               8.0
# Length                 219.0
# Wheelbase              119.0
# Width                   78.0
# Turn.circle             45.0
# Rear.seat.room          36.0
# Luggage.room            22.0
# Weight                4105.0
# dtype: float64

# %%
df.min()
# Out:
# Min.Price                NaN
# Price                    7.4
# Max.Price                7.9
# MPG.city                15.0
# MPG.highway             20.0
# EngineSize               1.0
# Horsepower              55.0
# RPM                   3800.0
# Rev.per.mile          1320.0
# Fuel.tank.capacity       9.2
# Passengers               2.0
# Length                 141.0
# Wheelbase               90.0
# Width                   60.0
# Turn.circle             32.0
# Rear.seat.room          19.0
# Luggage.room             6.0
# Weight                1695.0
# dtype: float64

# %%
df.median()
# Out:
# Min.Price                 NaN
# Price                   17.70
# Max.Price               19.15
# MPG.city                21.00
# MPG.highway             28.00
# EngineSize               2.30
# Horsepower             140.00
# RPM                   5200.00
# Rev.per.mile          2360.00
# Fuel.tank.capacity      16.50
# Passengers               5.00
# Length                 181.00
# Wheelbase              103.00
# Width                   69.00
# Turn.circle             39.00
# Rear.seat.room          27.50
# Luggage.room            14.00
# Weight                3085.00
# dtype: float64

# %%
df.std()
# Out:
# Min.Price                    NaN
# Price                   9.724280
# Max.Price              10.696563
# MPG.city                5.841520
# MPG.highway             5.370293
# EngineSize              1.045845
# Horsepower             53.455204
# RPM                   605.554811
# Rev.per.mile          486.916616
# Fuel.tank.capacity      3.375748
# Passengers              1.045953
# Length                 14.792651
# Wheelbase               6.856317
# Width                   3.778023
# Turn.circle             3.304157
# Rear.seat.room          3.018129
# Luggage.room            3.120824
# Weight                600.129993
# dtype: float64

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
df[['Min.Price', 'Max.Price']].isnull()
# Out:
#     Min.Price  Max.Price
# 0       False      False
# 1       False      False
# 2       False      False
# 3        True      False
# 4        True       True
# ..        ...        ...
# 88      False      False
# 89      False      False
# 90      False      False
# 91      False      False
# 92      False      False
#
# [93 rows x 2 columns]

# %%
df[['Min.Price', 'Max.Price']].isnull()  == df.mean()
# Out:
#     EngineSize  Fuel.tank.capacity  Horsepower  Length  Luggage.room  \
# 0        False               False       False   False         False
# 1        False               False       False   False         False
# 2        False               False       False   False         False
# 3        False               False       False   False         False
# 4        False               False       False   False         False
# ..         ...                 ...         ...     ...           ...
# 88       False               False       False   False         False
# 89       False               False       False   False         False
# 90       False               False       False   False         False
# 91       False               False       False   False         False
# 92       False               False       False   False         False
#
#     MPG.city  MPG.highway  Max.Price  Min.Price  Passengers  Price    RPM  \
# ...

# %%
car_Manufacturers = df.groupby('Manufacturer')
priceDf = car_Manufacturers['Manufacturer','Price'].max().sort_values('Price', ascending=True)
priceDf
# Out:
#                 Manufacturer  Price
# Manufacturer
# Suzuki                Suzuki    8.6
# Geo                      Geo   12.5
# Hyundai              Hyundai   13.9
# Plymouth            Plymouth   14.4
# Mercury              Mercury   14.9
# Acura                  Acura   15.9
# Eagle                  Eagle   19.3
# Subaru                Subaru   19.5
# Honda                  Honda   19.8
# Oldsmobile        Oldsmobile   20.7
# Ford                    Ford   20.9
# Nissan                Nissan   21.5
# Toyota                Toyota   22.7
# Volvo                  Volvo   22.7
# Volkswagen        Volkswagen   23.3
# Pontiac              Pontiac   24.4
# Dodge                  Dodge   25.8
# Mitsubishi        Mitsubishi   26.1
# Buick                  Buick   26.3
# Lexus                  Lexus   28.0
# Saab                    Saab   28.7
# Chrysler            Chrysler   29.5
# BMW                      BMW   30.0
# Mazda                  Mazda   32.5
# ...
